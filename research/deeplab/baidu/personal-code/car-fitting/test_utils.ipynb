# %%
import mxnet as mx
import numpy as np
import sys
sys.path.insert(0, '../DeMoN/')
sys.path.insert(0, './')
import utils.utils as uts

# %%
# %matplotlib inline

log_file = './log/sim_policy_occ.log' 
log_file = './log/policy-demon-crop-apollo.log'
log_file = './log/crop_kitti_apollo_init.log'
log_file = './log/apollo-supervise-psm-stereo.log'
log_file = './log/apollo-super.log'
log_file = './log/tf_model/log_train.txt'
log_file = './log/apollo-super-disc.log'

# log_file = './log/crop_kitti_no_init.log'
uts.plot_mxnet_log(log_file, 'median_theta', [0.0, 88.8])
uts.plot_mxnet_log(log_file, 'median_xyz', [0.0, 96.5])
# Out:
# maxval37.877577 epoch57
# minval3.854376 epoch4
# maxval12.660462 epoch120
# minval9.339808 epoch43
